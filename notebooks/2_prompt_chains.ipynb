# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
prompts = [
    {"role": "system", "content":"You are a JavaScript Developer ?"},
    {"role": "user", "content":"Difference b/w map and filter ?"}
    ]

res = llm.invoke(prompts)
print(res.content)
# Out:
# Yes, I am a JavaScript Developer! I can definitely help you understand the difference between `map` and `filter` in JavaScript. They are both powerful array methods, but they serve distinct purposes.
#
# Here's a breakdown of their differences:
#
# ## `map()`
#
# **Purpose:** To **transform** each element in an array into something else, creating a **new array** of the same length.
#
# **How it works:**
# * It iterates over each element of the original array.
# * For each element, it executes a provided callback function.
# * The callback function receives the current element, its index, and the original array as arguments.
# * The **return value** of the callback function for each element becomes the corresponding element in the **new array**.
#
# **Key Characteristics:**
# * **Transformation:** Its primary goal is to change the data.
# * **New Array:** Always returns a new array.
# ...

# %%
prompts = [
    {"role": "system", "content":"You are a Python Developer ?"},
    {"role": "user", "content":"Difference b/w map and filter ?"}
    ]

res = llm.invoke(prompts)
print(res.content)
# Out:
# Yes, I am a Python Developer! I can definitely explain the difference between `map()` and `filter()` in Python. They are both built-in functions that are very useful for working with iterables (like lists, tuples, etc.) and applying functions to them, but they serve distinct purposes.
#
# Here's a breakdown of their differences:
#
# ## `map()`
#
# **Purpose:** `map()` applies a given function to **each item** of an iterable and returns an **iterator** containing the results. It's about transforming each element.
#
# **Syntax:**
# ```python
# map(function, iterable1, iterable2, ...)
# ```
#
# *   `function`: The function to apply to each item.
# *   `iterable1`, `iterable2`, ...: One or more iterables. If multiple iterables are provided, the function must accept that many arguments, and `map()` will stop when the shortest iterable is exhausted.
#
# **Key Characteristics:**
#
# *   **Transformation:** It transforms each element into something else.
# ...

# %%
prompts = [
    {"role": "system", "content":"You are a translator and translate input into hindi ?"},
    {"role": "user", "content":"I love to play chess"}
    ]

res = llm.invoke(prompts)
print(res.content)
# Out:
# मुझे शतरंज खेलना बहुत पसंद है।

# %% [markdown]
# ### Prompt Templates - Dynamic Prompt

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
out = StrOutputParser()

# %%
#### My Self Chain Node

def transform_case(result: str):
    return result.upper()

# %%
prompts = ChatPromptTemplate.from_messages([
    {"role": "system", "content":"You are a translator and translate input into {language} ?"},
    {"role": "user", "content":"{query}"}
])

# %%
# final_prompts = prompts.format_messages(language="hinglish", query="I love to play chess")
# res = llm .invoke(final_prompts)
# print(res.content)

# %% [markdown]
# ### Chains - Runnable

# %%
# res = llm.invoke(prompts.invoke({"language":"hindi", "query": "I love Javscript and Python !"}).messages)
# res.content
# Out:
# 'मुझे जावास्क्रिप्ट और पायथन बहुत पसंद हैं!'

# %%
chains = prompts | llm | out | transform_case

# %%
res = chains.invoke({"language":"hinglish", "query": "I love Javscript and Python with Lanchain !"})
print(res)
# Out:
# MUJHE JAVASCRIPT AUR PYTHON, LANCHAIN KE SAATH BAHUT PASAND HAI!
